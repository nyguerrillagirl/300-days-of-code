# %%
import pandas as pd
dogs = pd.read_csv("dogs.csv")
print(dogs)
# Out:
#       name        breed  color  height_cm  weight_kg
# 0    Bella     Labrador  Brown         56         25
# 1  Charlie       Poodle  Black         43         23
# 2     Lucy    Chow Chow  Brown         46         22
# 3   Cooper    Schnauzer   Gray         49         17
# 4      Max     Labrador  Black         59         29
# 5   Stella    Chihauhau    Tan         18          2
# 6   Bernie  St. Bernard  White         77         74

# %%
dogs.columns
# Out:
# Index(['name', 'breed', 'color', 'height_cm', 'weight_kg'], dtype='object')

# %%
dogs.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
dogs_ind = dogs.set_index("name")
dogs_ind
# Out:
#                breed  color  height_cm  weight_kg
# name
# Bella       Labrador  Brown         56         25
# Charlie       Poodle  Black         43         23
# Lucy       Chow Chow  Brown         46         22
# Cooper     Schnauzer   Gray         49         17
# Max         Labrador  Black         59         29
# Stella     Chihauhau    Tan         18          2
# Bernie   St. Bernard  White         77         74

# %%
new_dogs_ind = dogs_ind.reset_index()
new_dogs_ind
# Out:
#       name        breed  color  height_cm  weight_kg
# 0    Bella     Labrador  Brown         56         25
# 1  Charlie       Poodle  Black         43         23
# 2     Lucy    Chow Chow  Brown         46         22
# 3   Cooper    Schnauzer   Gray         49         17
# 4      Max     Labrador  Black         59         29
# 5   Stella    Chihauhau    Tan         18          2
# 6   Bernie  St. Bernard  White         77         74

# %%
new_dogs_ind = dogs_ind.reset_index(drop=True)
new_dogs_ind
# Out:
#          breed  color  height_cm  weight_kg
# 0     Labrador  Brown         56         25
# 1       Poodle  Black         43         23
# 2    Chow Chow  Brown         46         22
# 3    Schnauzer   Gray         49         17
# 4     Labrador  Black         59         29
# 5    Chihauhau    Tan         18          2
# 6  St. Bernard  White         77         74

# %%
dogs
# Out:
#       name        breed  color  height_cm  weight_kg
# 0    Bella     Labrador  Brown         56         25
# 1  Charlie       Poodle  Black         43         23
# 2     Lucy    Chow Chow  Brown         46         22
# 3   Cooper    Schnauzer   Gray         49         17
# 4      Max     Labrador  Black         59         29
# 5   Stella    Chihauhau    Tan         18          2
# 6   Bernie  St. Bernard  White         77         74

# %%
dogs[dogs["name"].isin(["Bella", "Stella"])]
# Out:
#      name      breed  color  height_cm  weight_kg
# 0   Bella   Labrador  Brown         56         25
# 5  Stella  Chihauhau    Tan         18          2

# %%
dogs_ind
# Out:
#                breed  color  height_cm  weight_kg
# name
# Bella       Labrador  Brown         56         25
# Charlie       Poodle  Black         43         23
# Lucy       Chow Chow  Brown         46         22
# Cooper     Schnauzer   Gray         49         17
# Max         Labrador  Black         59         29
# Stella     Chihauhau    Tan         18          2
# Bernie   St. Bernard  White         77         74

# %%
dogs_ind.loc[["Bella", "Stella"]]
# Out:
#             breed  color  height_cm  weight_kg
# name
# Bella    Labrador  Brown         56         25
# Stella  Chihauhau    Tan         18          2

# %%
dogs
# Out:
#       name        breed  color  height_cm  weight_kg
# 0    Bella     Labrador  Brown         56         25
# 1  Charlie       Poodle  Black         43         23
# 2     Lucy    Chow Chow  Brown         46         22
# 3   Cooper    Schnauzer   Gray         49         17
# 4      Max     Labrador  Black         59         29
# 5   Stella    Chihauhau    Tan         18          2
# 6   Bernie  St. Bernard  White         77         74

# %%
dogs_ind2 = dogs.set_index("breed")
dogs_ind2
# Out:
#                 name  color  height_cm  weight_kg
# breed
# Labrador       Bella  Brown         56         25
# Poodle       Charlie  Black         43         23
# Chow Chow       Lucy  Brown         46         22
# Schnauzer     Cooper   Gray         49         17
# Labrador         Max  Black         59         29
# Chihauhau     Stella    Tan         18          2
# St. Bernard   Bernie  White         77         74

# %%
dogs_ind2.index
# Out:
# Index(['Labrador', 'Poodle', 'Chow Chow', 'Schnauzer', 'Labrador', 'Chihauhau',
#        'St. Bernard'],
#       dtype='object', name='breed')

# %%
dogs_ind2.loc["Labrador"]
# Out:
#            name  color  height_cm  weight_kg
# breed
# Labrador  Bella  Brown         56         25
# Labrador    Max  Black         59         29

# %%
dogs_ind3 = dogs.set_index(["breed", "color"])
dogs_ind3
# Out:
#                       name  height_cm  weight_kg
# breed       color
# Labrador    Brown    Bella         56         25
# Poodle      Black  Charlie         43         23
# Chow Chow   Brown     Lucy         46         22
# Schnauzer   Gray    Cooper         49         17
# Labrador    Black      Max         59         29
# Chihauhau   Tan     Stella         18          2
# St. Bernard White   Bernie         77         74

# %%
dogs_ind3.loc[["Labrador", "Chihauhau"]]
# Out:
#                    name  height_cm  weight_kg
# breed     color
# Labrador  Brown   Bella         56         25
#           Black     Max         59         29
# Chihauhau Tan    Stella         18          2

# %%
dogs_ind3.loc[[("Labrador", "Brown"), ("Chihauhau", "Tan")]]
# Out:
#                    name  height_cm  weight_kg
# breed     color
# Labrador  Brown   Bella         56         25
# Chihauhau Tan    Stella         18          2

# %%
dogs_ind3
# Out:
#                       name  height_cm  weight_kg
# breed       color
# Labrador    Brown    Bella         56         25
# Poodle      Black  Charlie         43         23
# Chow Chow   Brown     Lucy         46         22
# Schnauzer   Gray    Cooper         49         17
# Labrador    Black      Max         59         29
# Chihauhau   Tan     Stella         18          2
# St. Bernard White   Bernie         77         74

# %%
dogs_ind3.sort_index()
# Out:
#                       name  height_cm  weight_kg
# breed       color
# Chihauhau   Tan     Stella         18          2
# Chow Chow   Brown     Lucy         46         22
# Labrador    Black      Max         59         29
#             Brown    Bella         56         25
# Poodle      Black  Charlie         43         23
# Schnauzer   Gray    Cooper         49         17
# St. Bernard White   Bernie         77         74

# %%
dogs_ind3.sort_index(level=["color", "breed"], ascending=[True, False])
# Out:
#                       name  height_cm  weight_kg
# breed       color
# Poodle      Black  Charlie         43         23
# Labrador    Black      Max         59         29
#             Brown    Bella         56         25
# Chow Chow   Brown     Lucy         46         22
# Schnauzer   Gray    Cooper         49         17
# Chihauhau   Tan     Stella         18          2
# St. Bernard White   Bernie         77         74

# %%
breeds = ["Labrador", "Poodle", "Chow Chow", "Schnauzer", "Labrador", "Chihauhau", "St. Bernard"]
breeds
# Out:
# ['Labrador',
#  'Poodle',
#  'Chow Chow',
#  'Schnauzer',
#  'Labrador',
#  'Chihauhau',
#  'St. Bernard']

# %%
breeds[2:5]
# Out:
# ['Chow Chow', 'Schnauzer', 'Labrador']

# %%
breeds[:3]
# Out:
# ['Labrador', 'Poodle', 'Chow Chow']

# %%
breeds[:]
# Out:
# ['Labrador',
#  'Poodle',
#  'Chow Chow',
#  'Schnauzer',
#  'Labrador',
#  'Chihauhau',
#  'St. Bernard']

# %%
dogs
# Out:
#       name        breed  color  height_cm  weight_kg
# 0    Bella     Labrador  Brown         56         25
# 1  Charlie       Poodle  Black         43         23
# 2     Lucy    Chow Chow  Brown         46         22
# 3   Cooper    Schnauzer   Gray         49         17
# 4      Max     Labrador  Black         59         29
# 5   Stella    Chihauhau    Tan         18          2
# 6   Bernie  St. Bernard  White         77         74

# %%
dogs_srt = (dogs.set_index(["breed", "color"])).sort_index()
dogs_srt
# Out:
#                       name  height_cm  weight_kg
# breed       color
# Chihauhau   Tan     Stella         18          2
# Chow Chow   Brown     Lucy         46         22
# Labrador    Black      Max         59         29
#             Brown    Bella         56         25
# Poodle      Black  Charlie         43         23
# Schnauzer   Gray    Cooper         49         17
# St. Bernard White   Bernie         77         74

# %%
dogs_srt.loc["Chow Chow": "Poodle"]
# Out:
#                     name  height_cm  weight_kg
# breed     color
# Chow Chow Brown     Lucy         46         22
# Labrador  Black      Max         59         29
#           Brown    Bella         56         25
# Poodle    Black  Charlie         43         23

# %%
dogs_srt.loc["Tan":"Gray"]
# Out:
# Empty DataFrame
# Columns: [name, height_cm, weight_kg]
# Index: []

# %%
dogs_srt.loc[("Labrador", "Brown"): ("Schnauzer", "Gray")]
# Out:
#                     name  height_cm  weight_kg
# breed     color
# Labrador  Brown    Bella         56         25
# Poodle    Black  Charlie         43         23
# Schnauzer Gray    Cooper         49         17

# %%
# slicing columns
dogs_srt.loc[:, "name": "height_cm"]
# Out:
#                       name  height_cm
# breed       color
# Chihauhau   Tan     Stella         18
# Chow Chow   Brown     Lucy         46
# Labrador    Black      Max         59
#             Brown    Bella         56
# Poodle      Black  Charlie         43
# Schnauzer   Gray    Cooper         49
# St. Bernard White   Bernie         77

# %%
# Slice twice
dogs_srt.loc[("Labrador", "Brown"):("Schnauzer", "Gray"),"name":"height_cm"]
# Out:
#                     name  height_cm
# breed     color
# Labrador  Brown    Bella         56
# Poodle    Black  Charlie         43
# Schnauzer Gray    Cooper         49

# %%
dogs2 = pd.read_csv("dogs2.csv")
dogs2
# Out:
#       name        breed  color  height_cm  weight_kg date_of_birth
# 0    Bella     Labrador  Brown         56         25    2013-07-01
# 1  Charlie       Poodle  Black         43         23    2016-09-16
# 2     Lucy    Chow Chow  Brown         46         22    2014-08-25
# 3   Cooper    Schnauzer   Gray         49         17    2011-12-11
# 4      Max     Labrador  Black         59         29    2017-01-20
# 5   Stella    Chihauhau    Tan         18          2    2015-04-20
# 6   Bernie  St. Bernard  White         77         74    2018-02-27

# %%
dogs = (dogs2.set_index("date_of_birth")).sort_index()
dogs
# Out:
#                   name        breed  color  height_cm  weight_kg
# date_of_birth
# 2011-12-11      Cooper    Schnauzer   Gray         49         17
# 2013-07-01       Bella     Labrador  Brown         56         25
# 2014-08-25        Lucy    Chow Chow  Brown         46         22
# 2015-04-20      Stella    Chihauhau    Tan         18          2
# 2016-09-16     Charlie       Poodle  Black         43         23
# 2017-01-20         Max     Labrador  Black         59         29
# 2018-02-27      Bernie  St. Bernard  White         77         74

# %%
# slicing by dates
dogs.loc["2014-08-25":"2016-09-16"]
# Out:
#                   name      breed  color  height_cm  weight_kg
# date_of_birth
# 2014-08-25        Lucy  Chow Chow  Brown         46         22
# 2015-04-20      Stella  Chihauhau    Tan         18          2
# 2016-09-16     Charlie     Poodle  Black         43         23

# %%
# slicing by partial dates
dogs.loc["2014":"2016"]
# Out:
#                  name      breed  color  height_cm  weight_kg
# date_of_birth
# 2014-08-25       Lucy  Chow Chow  Brown         46         22
# 2015-04-20     Stella  Chihauhau    Tan         18          2

# %%
# subsetting by row/col number
dogs.iloc[2:5, 1:4]
# Out:
#                    breed  color  height_cm
# date_of_birth
# 2014-08-25     Chow Chow  Brown         46
# 2015-04-20     Chihauhau    Tan         18
# 2016-09-16        Poodle  Black         43
